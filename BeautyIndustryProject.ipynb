# %%
pwd
# Out:
# '/Users/comfortuji'

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/comfortuji/Downloads/00. InfoProduct.csv')
df
# Out:
#         Category            Make                                  Product  \
# 0    Night Cream       Hada Labo                           Perfect 3D Gel
# 1      Face Mist            PIXY              Aqua Beauty Protecting Mist
# 2    Night Cream          Wardah                   Lightening Night Cream
# 3      Face Mist           Avene                     Thermal Spring Water
# 4    Night Cream          Wardah                 White Secret Night Cream
# ..           ...             ...                                      ...
# 856        Toner  Paula's Choice  Skin Perfecting 2% BHA Liquid Exfoliant
# 857        Toner           Cosrx         Natural BHA Skin Returning A-Sol
# 858        Toner           Ovale                            Facial Lotion
# 859        Toner           Cosrx        Centella Water Alcohol-Free Toner
# 860        Toner         Mamonde                         Rose Water Toner
#
#            Price  OverallRating  Reviewer
# ...

# %%
df.head()
# Out:
#       Category       Make                      Product        Price  \
# 0  Night Cream  Hada Labo               Perfect 3D Gel   Rp. 91.000
# 1    Face Mist       PIXY  Aqua Beauty Protecting Mist   Rp. 27.000
# 2  Night Cream     Wardah       Lightening Night Cream        Rp. 0
# 3    Face Mist      Avene         Thermal Spring Water  Rp. 199.000
# 4  Night Cream     Wardah     White Secret Night Cream   Rp. 98.000
#
#    OverallRating  Reviewer
# 0            3.8     978.0
# 1            4.2    3851.0
# 2            3.5     806.0
# 3            4.4    1239.0
# 4            3.6     572.0

# %%
df.drop("Make", axis=1, inplace=True)

# %%
df.head()
# Out:
#       Category                      Product        Price  OverallRating  \
# 0  Night Cream               Perfect 3D Gel   Rp. 91.000            3.8
# 1    Face Mist  Aqua Beauty Protecting Mist   Rp. 27.000            4.2
# 2  Night Cream       Lightening Night Cream        Rp. 0            3.5
# 3    Face Mist         Thermal Spring Water  Rp. 199.000            4.4
# 4  Night Cream     White Secret Night Cream   Rp. 98.000            3.6
#
#    Reviewer
# 0     978.0
# 1    3851.0
# 2     806.0
# 3    1239.0
# 4     572.0

# %%
df
# Out:
#         Category                                  Product        Price  \
# 0    Night Cream                           Perfect 3D Gel   Rp. 91.000
# 1      Face Mist              Aqua Beauty Protecting Mist   Rp. 27.000
# 2    Night Cream                   Lightening Night Cream        Rp. 0
# 3      Face Mist                     Thermal Spring Water  Rp. 199.000
# 4    Night Cream                 White Secret Night Cream   Rp. 98.000
# ..           ...                                      ...          ...
# 856        Toner  Skin Perfecting 2% BHA Liquid Exfoliant  Rp. 390.000
# 857        Toner         Natural BHA Skin Returning A-Sol        Rp. 0
# 858        Toner                            Facial Lotion   Rp. 15.000
# 859        Toner        Centella Water Alcohol-Free Toner  Rp. 157.000
# 860        Toner                         Rose Water Toner  Rp. 193.300
#
#      OverallRating  Reviewer
# 0              3.8     978.0
# 1              4.2    3851.0
# ...

# %%
col=df.columns.to_list()
col
# Out:
# ['Category', 'Product', 'Price', 'OverallRating', 'Reviewer']

# %%
category= [df['Category'].to_list()]
product= [df['Product'].to_list()]
rating= [df['OverallRating'].to_list()]
review= [df['Reviewer'].to_list()]

# %%
category
# Out:
# [['Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Face Mist',
#   'Night Cream',
#   'Face Mist',
#   'Face Mist',
#   'Face Mist',
# ...

# %%
product
# Out:
# [['Perfect 3D Gel',
#   'Aqua Beauty Protecting Mist',
#   'Lightening Night Cream',
#   'Thermal Spring Water',
#   'White Secret Night Cream',
#   'Mineral Water Spray',
#   'White Expert Replenishing Night Cream',
#   'Aloe Vera 92% Soothing Gel Mist',
#   'Light Complete White Speed Multi-Action Whitening Serum Cream Night Restore',
#   'C-defense Face Mist',
#   'White Perfect Clinical Overnight Treatment',
#   'NaPCA Moisture Mist',
#   'Vitamin E Nourishing Night Cream',
#   'Pure Rose Water',
#   'Vitamin E Gel Moisture Cream',
#   'Vitamin C Energising Face Mist',
#   'White Aqua Gel Cream Night Cream',
#   'Fresh Face Mist',
#   'Midnight Blue Calming Cream',
#   'Hydrating Mist',
#   'Tea Tree Oil Blemish Fade Night Lotion',
#   'Daily Nourishing Face Mist',
#   'Shirojyun Ultimate Whitening Cream',
#   'Hydrabio Brume Soothing Refreshing Water',
#   'Renew You Anti Aging Night Cream',
#   'Facial Spray With Aloe Herbs And Rosewater',
#   'Night Extra Brightening Cream',
# ...

# %%
rating
# Out:
# [[3.8,
#   4.2,
#   3.5,
#   4.4,
#   3.6,
#   3.8,
#   3.6,
#   4.0,
#   3.2,
#   3.7,
#   3.8,
#   4.1,
#   3.7,
#   4.2,
#   4.1,
#   3.0,
#   3.5,
#   3.6,
#   4.1,
#   4.7,
#   3.3,
#   3.7,
#   3.5,
#   4.2,
#   3.7,
#   4.2,
#   4.3,
#   3.1,
#   4.0,
#   3.9,
#   3.1,
#   4.2,
#   4.7,
#   4.3,
#   3.8,
#   3.8,
#   3.9,
#   3.5,
#   3.7,
#   4.1,
#   4.4,
#   4.2,
#   3.4,
#   4.2,
#   3.9,
#   4.1,
#   3.7,
#   3.3,
#   3.4,
#   4.5,
#   4.6,
#   4.4,
#   3.8,
#   4.0,
#   3.3,
#   3.9,
#   3.8,
#   3.8,
#   3.7,
#   4.6,
#   4.5,
#   4.6,
#   3.5,
#   3.9,
#   3.7,
#   4.4,
#   3.7,
#   4.0,
#   3.8,
#   4.3,
#   3.5,
#   4.2,
#   4.4,
#   4.0,
#   4.1,
#   3.7,
#   4.1,
#   4.3,
#   4.4,
#   4.2,
#   4.1,
#   4.0,
#   3.3,
#   3.1,
#   3.4,
#   3.2,
#   3.2,
#   3.8,
#   3.1,
#   3.5,
#   3.6,
#   3.3,
#   3.4,
#   3.8,
#   3.3,
#   3.8,
#   3.4,
#   3.5,
#   3.5,
#   4.1,
#   4.5,
#   3.7,
#   4.2,
#   3.1,
#   4.3,
#   4.0,
#   4.0,
#   3.7,
#   4.3,
#   4.1,
#   4.0,
# ...

# %%
review
# Out:
# [[978.0,
#   3851.0,
#   806.0,
#   1239.0,
#   572.0,
#   979.0,
#   423.0,
#   424.0,
#   409.0,
#   354.0,
#   363.0,
#   342.0,
#   287.0,
#   305.0,
#   270.0,
#   233.0,
#   258.0,
#   232.0,
#   242.0,
#   210.0,
#   227.0,
#   200.0,
#   226.0,
#   184.0,
#   220.0,
#   178.0,
#   206.0,
#   157.0,
#   198.0,
#   148.0,
#   189.0,
#   132.0,
#   172.0,
#   96.0,
#   169.0,
#   90.0,
#   164.0,
#   82.0,
#   163.0,
#   82.0,
#   152.0,
#   82.0,
#   146.0,
#   80.0,
#   134.0,
#   74.0,
#   133.0,
#   73.0,
#   130.0,
#   71.0,
#   71.0,
#   127.0,
#   63.0,
#   63.0,
#   53.0,
#   50.0,
#   127.0,
#   58.0,
#   123.0,
#   54.0,
#   119.0,
#   54.0,
#   117.0,
#   46.0,
#   112.0,
#   41.0,
#   105.0,
#   39.0,
#   102.0,
#   37.0,
#   101.0,
#   37.0,
#   99.0,
#   37.0,
#   93.0,
#   36.0,
#   90.0,
#   87.0,
#   85.0,
#   866.0,
#   81.0,
#   1217.0,
#   900.0,
#   860.0,
#   838.0,
#   687.0,
#   660.0,
#   582.0,
#   560.0,
#   542.0,
#   458.0,
#   411.0,
#   403.0,
# ...

# %%
price= [df['Price'].to_list()]

# %%
price
# Out:
# [['Rp. 91.000',
#   'Rp. 27.000',
#   'Rp. 0',
#   'Rp. 199.000',
#   'Rp. 98.000',
#   'Rp. 160.000',
#   'Rp. 103.000',
#   'Rp. 100.000',
#   'Rp. 54.100',
#   'Rp. 36.000',
#   'Rp. 150.000',
#   'Rp. 113.000',
#   'Rp. 199.000',
#   'Rp. 39.000',
#   'Rp. 199.000',
#   'Rp. 179.000',
#   'Rp. 50.000',
#   'Rp. 30.000',
#   'Rp. 450.000',
#   'Rp. 108.000',
#   'Rp. 179.000',
#   'Rp. 31.000',
#   'Rp. 70.000',
#   'Rp. 99.000',
#   'Rp. 100.000',
#   'Rp. 175.620',
#   'Rp. 48.000',
#   'Rp. 40.000',
#   'Rp. 145.900',
#   'Rp. 130.000',
#   'Rp. 33.000',
#   'Rp. 0',
#   'Rp. 65.000',
#   'Rp. 249.000',
#   'Rp. 28.000',
#   'Rp. 360.000',
#   'Rp. 220.000',
#   'Rp. 159.000',
#   'Rp. 242.000',
#   'Rp. 0',
#   'Rp. 1.500.000',
#   'Rp. 200.000',
#   'Rp. 119.000',
#   'Rp. 120.000',
#   'Rp. 28.000',
#   'Rp. 300.000',
#   'Rp. 74.900',
#   'Rp. 33.000',
#   'Rp. 70.000',
#   'Rp. 35.000',
#   'Rp. 35.000',
#   'Rp. 250.000',
#   'Rp. 30.000',
#   'Rp. 30.000',
# ...

# %%
dic = {col[0]:category,
      col[1]:product,
      col[2]:price,
      col[3]:rating,
      col[4]:review}

# %%
df=pd.DataFrame(dic)

# %%
df
# Out:
#                                             Category  \
# 0  [Night Cream, Face Mist, Night Cream, Face Mis...
#
#                                              Product  \
# 0  [Perfect 3D Gel, Aqua Beauty Protecting Mist, ...
#
#                                                Price  \
# 0  [Rp. 91.000, Rp. 27.000, Rp. 0, Rp. 199.000, R...
#
#                                        OverallRating  \
# 0  [3.8, 4.2, 3.5, 4.4, 3.6, 3.8, 3.6, 4.0, 3.2, ...
#
#                                             Reviewer
# 0  [978.0, 3851.0, 806.0, 1239.0, 572.0, 979.0, 4...

# %%
df.to_excel('F:\Tableau BP\beautyindustry.xlsx')
